# %%
import requests
from pyquery import PyQuery as pq

# %%
html = 'http://ilxdh.com/'
doc = pq(html)

doc1 = doc('.main-nav ul li').items()
for item in doc1:
    print(item.text())
    if item('a').attr('href'):
        print(item('a').attr('href'))
    # save in file    
    with open('url.txt','a') as f:
        item('.big-cat')
        if item('a').attr('href'):
            f.write(item.text())
            f.write(item('a').attr('href'))
        f.write('\n')
# Out:
# 便携生活
# 购 物
# 直 播
# 财经金融
# 社 区
# 游 戏
# 新闻报刊
# IT资讯
# 热点排行榜
# 快递查询
# https://www.kuaidi100.com/
# 快递申诉
# http://sswz.spb.gov.cn/
# 12306
# http://www.12306.cn/
# 淘宝网
# https://www.taobao.com/
# 天猫
# https://www.tmall.com/
# 历史上的今天
# http://www.todayonhistory.com/
# 微信网页版
# https://wx.qq.com/
# ip查询
# https://www.ipip.net/
# 万年历
# http://hao.360.cn/rili/
# 163邮箱
# https://mail.163.com/
# QQ邮箱
# https://mail.qq.com/
# Gmail
# https://accounts.google.com/ServiceLogin?service=mail&continue=https://mail.google.com/mail/&hl=zh-CN#identifier
# 新浪邮箱
# http://mail.sina.com.cn/
# 126邮箱
# https://mail.126.com/
# 搜狐邮箱
# https://mail.sohu.com/fe/#/login
# 百度网盘
# https://pan.baidu.com/
# 115网盘
# http://115.com/
# 微云
# https://www.weiyun.com/
# 蓝奏云
# https://www.lanzou.com/
# 盛天云盘
# http://pan.stnts.com
# 百度地图
# https://map.baidu.com/
# 高德地图
# http://ditu.amap.com/
# 周公解梦
# http://hao.360.cn/zgjm.html
# 星座
# http://hao.360.cn/xingzuo.html
# 全部
# 常用
# 秒杀
# 团购
# 历史价格
# 淘宝优惠券
# http://lolbaicai.com/
# ...

# %%
import requests
from pyquery import PyQuery as pq

# %%
def longxuan():
    html = 'http://ilxdh.com/'
    doc = pq(html)
    doc1 = doc('.main-nav ul li').items()
    for item in doc1:
        print(item.text())
        if item('a').attr('href'):
            print(item('a').attr('href'))
        save_to_text(item)

def save_to_text(item):
    with open('url1.txt','a') as f:
        item('.big-cat')
        if item('a').attr('href'):
            f.write(item.text())
            f.write(item('a').attr('href'))
        f.write('\n')

if __name__ =="__main__":
    a = longxuan()
# Out:
# 便携生活
# 购 物
# 直 播
# 财经金融
# 社 区
# 游 戏
# 新闻报刊
# IT资讯
# 热点排行榜
# 快递查询
# https://www.kuaidi100.com/
# 快递申诉
# http://sswz.spb.gov.cn/
# 12306
# http://www.12306.cn/
# 淘宝网
# https://www.taobao.com/
# 天猫
# https://www.tmall.com/
# 历史上的今天
# http://www.todayonhistory.com/
# 微信网页版
# https://wx.qq.com/
# ip查询
# https://www.ipip.net/
# 万年历
# http://hao.360.cn/rili/
# 163邮箱
# https://mail.163.com/
# QQ邮箱
# https://mail.qq.com/
# Gmail
# https://accounts.google.com/ServiceLogin?service=mail&continue=https://mail.google.com/mail/&hl=zh-CN#identifier
# 新浪邮箱
# http://mail.sina.com.cn/
# 126邮箱
# https://mail.126.com/
# 搜狐邮箱
# https://mail.sohu.com/fe/#/login
# 百度网盘
# https://pan.baidu.com/
# 115网盘
# http://115.com/
# 微云
# https://www.weiyun.com/
# 蓝奏云
# https://www.lanzou.com/
# 盛天云盘
# http://pan.stnts.com
# 百度地图
# https://map.baidu.com/
# 高德地图
# http://ditu.amap.com/
# 周公解梦
# http://hao.360.cn/zgjm.html
# 星座
# http://hao.360.cn/xingzuo.html
# 全部
# 常用
# 秒杀
# 团购
# 历史价格
# 淘宝优惠券
# http://lolbaicai.com/
# ...
